# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:/Data Science/Symbiosis/Perform EDA on Temperature data Assignment/temperature.csv",parse_dates=["datetime"])
df.head()
# Out:
#              datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868185  291.533501  293.403141  296.608508   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...

# %%
df.head()
# Out:
#              datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868185  291.533501  293.403141  296.608508   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...

# %%
df=df.iloc[:,[0,-7]]

# %%
df.isna().sum()
# Out:
# datetime    0
# Boston      3
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# datetime    0
# Boston      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45250 entries, 1 to 45252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  45250 non-null  datetime64[ns]
#  1   Boston    45250 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.0 MB

# %%
# simple moving average

# %%
df
# Out:
#                  datetime      Boston
# 1     2012-10-01 13:00:00  287.170000
# 2     2012-10-01 14:00:00  287.186092
# 3     2012-10-01 15:00:00  287.231672
# 4     2012-10-01 16:00:00  287.277251
# 5     2012-10-01 17:00:00  287.322831
# ...                   ...         ...
# 45248 2017-11-29 20:00:00  288.080000
# 45249 2017-11-29 21:00:00  286.020000
# 45250 2017-11-29 22:00:00  283.940000
# 45251 2017-11-29 23:00:00  282.170000
# 45252 2017-11-30 00:00:00  280.650000
#
# [45250 rows x 2 columns]

# %%
df
# Out:
#                  datetime      Boston
# 1     2012-10-01 13:00:00  287.170000
# 2     2012-10-01 14:00:00  287.186092
# 3     2012-10-01 15:00:00  287.231672
# 4     2012-10-01 16:00:00  287.277251
# 5     2012-10-01 17:00:00  287.322831
# ...                   ...         ...
# 45248 2017-11-29 20:00:00  288.080000
# 45249 2017-11-29 21:00:00  286.020000
# 45250 2017-11-29 22:00:00  283.940000
# 45251 2017-11-29 23:00:00  282.170000
# 45252 2017-11-30 00:00:00  280.650000
#
# [45250 rows x 2 columns]

# %%
df["SMA4"]=df["Boston"].rolling(window=4).mean()

# %%
df
# Out:
#                  datetime      Boston        SMA4
# 1     2012-10-01 13:00:00  287.170000         NaN
# 2     2012-10-01 14:00:00  287.186092         NaN
# 3     2012-10-01 15:00:00  287.231672         NaN
# 4     2012-10-01 16:00:00  287.277251  287.216254
# 5     2012-10-01 17:00:00  287.322831  287.254461
# ...                   ...         ...         ...
# 45248 2017-11-29 20:00:00  288.080000  288.200000
# 45249 2017-11-29 21:00:00  286.020000  287.977500
# 45250 2017-11-29 22:00:00  283.940000  286.800000
# 45251 2017-11-29 23:00:00  282.170000  285.052500
# 45252 2017-11-30 00:00:00  280.650000  283.195000
#
# [45250 rows x 3 columns]

# %%
df["SMA10"]=df["Boston"].rolling(window=10).mean()

# %%
df
# Out:
#                  datetime      Boston        SMA4    SMA10
# 1     2012-10-01 13:00:00  287.170000         NaN      NaN
# 2     2012-10-01 14:00:00  287.186092         NaN      NaN
# 3     2012-10-01 15:00:00  287.231672         NaN      NaN
# 4     2012-10-01 16:00:00  287.277251  287.216254      NaN
# 5     2012-10-01 17:00:00  287.322831  287.254461      NaN
# ...                   ...         ...         ...      ...
# 45248 2017-11-29 20:00:00  288.080000  288.200000  285.867
# 45249 2017-11-29 21:00:00  286.020000  287.977500  286.071
# 45250 2017-11-29 22:00:00  283.940000  286.800000  286.112
# 45251 2017-11-29 23:00:00  282.170000  285.052500  285.930
# 45252 2017-11-30 00:00:00  280.650000  283.195000  285.571
#
# [45250 rows x 4 columns]

# %%
df_p=df.head(100)
df_p
# Out:
#                datetime      Boston        SMA4     SMA10
# 1   2012-10-01 13:00:00  287.170000         NaN       NaN
# 2   2012-10-01 14:00:00  287.186092         NaN       NaN
# 3   2012-10-01 15:00:00  287.231672         NaN       NaN
# 4   2012-10-01 16:00:00  287.277251  287.216254       NaN
# 5   2012-10-01 17:00:00  287.322831  287.254461       NaN
# ..                  ...         ...         ...       ...
# 96  2012-10-05 12:00:00  288.670000  288.743750  289.0285
# 97  2012-10-05 13:00:00  289.100000  288.785000  288.9945
# 98  2012-10-05 14:00:00  289.440000  288.942500  288.9975
# 99  2012-10-05 15:00:00  289.750000  289.240000  289.0535
# 100 2012-10-05 16:00:00  290.150000  289.610000  289.1565
#
# [100 rows x 4 columns]

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df_p["Boston"],label="Original")
plt.plot(df_p["SMA3"],label="SMA3")
plt.plot(df_p["SMA4"],label="SMA4")
plt.plot(df_p["SMA10"],label="SMA10")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\data science\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SMA3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-e73b4353cba2> in <module>
# ...

# %%
plt.plot(df_p["Boston"],label="Original")
plt.plot(df_p["SMA4"],label="SMA")
plt.legend()

# %%
#cumulative

# %%
df["CMA"]=df["Boston"].expanding(min_periods=4).mean()

# %%
df.head()

# %%
(287.170000+287.186092+287.231672+287.277251)/4

# %%
(287.170000+287.186092+287.231672+287.277251+287.322831)/5

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df["Boston"],label="Original")
plt.plot(df["CMA"],label="CMA")

# %%
#exponentially weighted function
#adjust= True   different formula
#adjust= False

# %%
df["EMA"]=df["Boston"].ewm(com=0.3).mean()
#com = center of mass
#ewm-span,halflife,aplpha,adjust

#alpha if it is given or you can do trail & error to see the smoothing effect

# %%
df.head()

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df["Boston"],label="Boston temp")
plt.plot(df["EMA"],label="EMA")

# %%
df_b=df.head(100)

# %%
df["EMA"]=df["Boston"].ewm(com=0.3).mean()

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df["Boston"],label="Boston temp")
plt.plot(df["EMA"],label="EMA")
